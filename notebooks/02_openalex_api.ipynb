# %%
import requests
import pandas as pd

# ==== CONFIGURATION ====
query = "orthokeratology contact lens"
per_page = 10
mailto = "adyl.elguamra@gmail.com"   # Replace with your email to join polite pool
api_key = ""  # Optional: replace with your key if you have one

# ==== API REQUEST ====
url = "https://api.openalex.org/works"
params = {
    "search": query,
    "per-page": per_page,
    "mailto": mailto
}

# Include API key if available
if api_key:
    params["api_key"] = api_key

response = requests.get(url, params=params)

# ==== HANDLE RESPONSE ====
if response.status_code == 200:
    data = response.json()
    works = data.get("results", [])
    
    # Extract info into list of dicts
    records = []
    for work in works:
        record = {
            "Title": work.get("title"),
            "Year": work.get("publication_year"),
            "Citations": work.get("cited_by_count"),
            "Authors": ", ".join([auth["author"]["display_name"] for auth in work.get("authorships", [])]),
            "OpenAlex ID": work.get("id"),
        }
        records.append(record)
    
    # Convert to DataFrame
    df = pd.DataFrame(records)
    display(df)

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    print(response.text)
# Out:
#                                                Title  Year  Citations  \
# 0  Myopia Control with Orthokeratology Contact Le...  2012        298
# 1  Long-term Efficacy of Orthokeratology Contact ...  2016        100
# 2  Myopia Control With Orthokeratology Contact Le...  2013         69
# 3  International survey of orthokeratology contac...  2018         52
# 4  The Topographical Effect of Optical Zone Diame...  2019         53
# 5  Malleability of the Ocular Surface in Response...  2008         46
# 6  Differences Between Overnight and Long-term We...  2009         55
# 7  Pachymetry Map of Corneal Epithelium in Childr...  2013         30
# 8  Unusual Morphology in Orthokeratology Contact ...  2003         26
# 9  Myopia Control with Orthokeratology Contact Le...  2009         23
#
#                                              Authors  \
# 0  Jacinto Santodomingo‐Rubido, César Villa Colla...
# 1  Jacinto Santodomingo‐Rubido, César Villa Colla...
# 2  Jacinto Santodomingo‐Rubido, César Villa Colla...
# 3  Philip B. Morgan, Nathan Efron, Craig A. Woods...
# 4  Gonzalo Carracedo, Teresa María Espinosa-Vidal...
# 5  Fenghe Lu, Trefford Simpson, Luigina Sorbara, ...
# 6  Xingwu Zhong, Xiaolian Chen, Ruo Zhong Xie, Ju...
# 7  Yishan Qian, Feng Xue, Jia Huang, Xiaomei Qu, ...
# 8                           Jenn‐Chyuan Wang, Li Lim
# 9  Jacinto Santodomingo‐Rubido, César Villa Colla...
#
#                         OpenAlex ID
# 0  https://openalex.org/W2162741876
# 1  https://openalex.org/W2534649079
# 2  https://openalex.org/W2042690660
# 3  https://openalex.org/W2900778411
# 4  https://openalex.org/W2907906149
# 5  https://openalex.org/W1970491371
# 6  https://openalex.org/W2104174547
# 7  https://openalex.org/W1975467366
# 8  https://openalex.org/W1991527061
# 9  https://openalex.org/W2068996152
